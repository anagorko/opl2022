# %% [markdown]
# # Branch and Cut
#
# "[**Revival of the Gomory cuts in the 1990's**](https://www.researchgate.net/publication/220462226_Revival_of_the_Gomory_cuts_in_the_1990's)", Gérard Cornuéjols

# %% [markdown]
# ![screenshot%20from%202021-05-12%2008-09-50.png](attachment:screenshot%20from%202021-05-12%2008-09-50.png)
# ![screenshot%20from%202021-05-12%2008-09-54.png](attachment:screenshot%20from%202021-05-12%2008-09-54.png)

# %%
import tsp

# %%
coords = tsp.Coords(5, seed=1)

# %%
coords.plot()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
P = coords.linear_problem()

# %%
coords.print_solution(P)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 1.0
# 3 --> 4: 1.0
# 4 --> 2: 1.0
# BINARY MULTIPLE SUBTOURS

# %%
coords.plot_solution(P)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tsp.find_subtours(P)
# Out:
# [[0, 1], [2, 3, 4]]

# %%
P1 = tsp.remove_subtour(P, [0,1])

# %%
coords.plot_solution(P1)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
P2 = tsp.remove_subtour(P, [2, 3, 4])

# %%
coords.print_solution(P2)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 0.6666666667
# 2 --> 4: 0.3333333333
# 3 --> 2: 0.3333333333
# 3 --> 4: 0.6666666667
# 4 --> 2: 0.6666666667
# 4 --> 3: 0.3333333333
# FRACTIONAL 2.17713553231494

# %%
show(P2)
# Out:
# WARNING: Some output was deleted.

# %%
P3, P4 = tsp.branch_on(P2, 2, 3)

# %%
coords.print_solution(P3)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 4: 1.0
# 3 --> 2: 1.0
# 4 --> 3: 1.0
# BINARY MULTIPLE SUBTOURS

# %%
coords.print_solution(P4)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.5
# 1 --> 4: 0.5
# 2 --> 3: 1.0
# 3 --> 2: 0.5
# 3 --> 4: 0.5
# 4 --> 0: 0.5
# 4 --> 2: 0.5
# FRACTIONAL 2.76771772609716

# %%
tree = tsp.Tree(coords)

# %%
tree.plot()

# %%
tree.solution(0)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(0)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 1.0
# 3 --> 4: 1.0
# 4 --> 2: 1.0
# BINARY MULTIPLE SUBTOURS

# %%
tree.remove_subtour(0, [2, 3, 4])

# %%
tree.plot()

# %%
tree.print(1)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 0.6666666667
# 2 --> 4: 0.3333333333
# 3 --> 2: 0.3333333333
# 3 --> 4: 0.6666666667
# 4 --> 2: 0.6666666667
# 4 --> 3: 0.3333333333
# FRACTIONAL 2.17713553231494

# %%
tree.branch_on(1, 23)

# %%
tree.plot()

# %%
tree.print(2)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.6666666667
# 1 --> 3: 0.3333333333
# 2 --> 0: 0.3333333333
# 2 --> 4: 0.6666666667
# 3 --> 2: 0.6666666667
# 3 --> 4: 0.3333333333
# 4 --> 2: 0.3333333333
# 4 --> 3: 0.6666666667
# FRACTIONAL 2.35494112163236

# %%
tree.print(3)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.5
# 1 --> 4: 0.5
# 2 --> 3: 1.0
# 3 --> 2: 0.5
# 3 --> 4: 0.5
# 4 --> 0: 0.5
# 4 --> 2: 0.5
# FRACTIONAL 2.76771772609716

# %%
tree.branch_on(3, 01)

# %%
tree.plot()

# %%
tree.solution(4)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.branch_on(5, 10)

# %%
tree.plot()

# %%
tree.solution(6)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(2)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.6666666667
# 1 --> 3: 0.3333333333
# 2 --> 0: 0.3333333333
# 2 --> 4: 0.6666666667
# 3 --> 2: 0.6666666667
# 3 --> 4: 0.3333333333
# 4 --> 2: 0.3333333333
# 4 --> 3: 0.6666666667
# FRACTIONAL 2.35494112163236

# %%
tree.branch_on(2, 10)

# %%
tree.plot()

# %%
tree.solution(8)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(9)
# Out:
# 0 --> 1: 0.6666666667
# 0 --> 3: 0.3333333333
# 1 --> 0: 1.0
# 2 --> 1: 0.3333333333
# 2 --> 4: 0.6666666667
# 3 --> 2: 0.6666666667
# 3 --> 4: 0.3333333333
# 4 --> 2: 0.3333333333
# 4 --> 3: 0.6666666667
# FRACTIONAL 2.44069219271819

# %%
tree.branch_on(9, 01)

# %%
tree.plot()

# %%
tree.solution(8)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree = tsp.Tree(coords)

# %%
tree.plot()

# %%
tree.remove_subtour(0, [2,3,4])

# %%
tree.plot()

# %%
tree.print(1)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 1.0
# 2 --> 3: 0.6666666667
# 2 --> 4: 0.3333333333
# 3 --> 2: 0.3333333333
# 3 --> 4: 0.6666666667
# 4 --> 2: 0.6666666667
# 4 --> 3: 0.3333333333
# FRACTIONAL 2.17713553231494

# %%
tree.gomory_cut(1)
# Out:
# Cutting on x_23 value 0.6666666667 (y21, x_32, y23, x_43, y25, x_12, y27, x_10, y29, x_01, x_40, x_24, x_30, x_23, x_34, y36, y37, y38, y39, y40, y41, y42, y43, y44, y45, y46, y47, y48, y49, y50, y51, y52, y53, y54, y55, y56, y33)

# %%
tree.plot()

# %%
tree.print(2)
# Out:
# 0 --> 1: 1.0
# 1 --> 0: 0.5
# 1 --> 3: 0.5
# 2 --> 0: 0.5
# 2 --> 3: 0.3333333333
# 2 --> 4: 0.1666666667
# 3 --> 2: 0.1666666667
# 3 --> 4: 0.8333333333
# 4 --> 2: 0.8333333333
# 4 --> 3: 0.1666666667
# FRACTIONAL 2.44384391631774

# %%
tree.branch_on(2, 10)

# %%
tree.plot()

# %%
tree.solution(3)
# Out:
# Graphics object consisting of 12 graphics primitives

# %%
tree.print(4)
# Out:
# 0 --> 1: 0.5
# 0 --> 3: 0.5
# 1 --> 0: 1.0
# 2 --> 3: 0.5
# 2 --> 4: 0.5
# 3 --> 1: 0.5
# 3 --> 4: 0.5
# 4 --> 2: 1.0
# FRACTIONAL 2.50069126248089

# %%
tree.branch_on(4, 01)

# %%
tree.plot()

# %%
tree.solution(5)
# Out:
# Graphics object consisting of 12 graphics primitives
